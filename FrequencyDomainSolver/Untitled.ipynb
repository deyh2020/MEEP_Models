# %%
import meep as mp
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt

n = 1.44
w = 1
r = 10
pad = 4
dpml = 2

sxy = 2*(r+w+pad+dpml)
cell_size = mp.Vector3(sxy,sxy)

pml_layers = [mp.PML(dpml)]

nonpml_vol = mp.Volume(mp.Vector3(), size=mp.Vector3(sxy-2*dpml,sxy-2*dpml))

geometry = [mp.Cylinder(radius=r+w, material=mp.Medium(index=n)),
            mp.Cylinder(radius=r)]

fcen = 1/1.5475

src = [mp.Source(mp.ContinuousSource(fcen),
                 component=mp.Ez,
                 center=mp.Vector3(r+0.1)),
       mp.Source(mp.ContinuousSource(fcen),
                 component=mp.Ez,
                 center=mp.Vector3(-(r+0.1)),
                 amplitude=-1)]

symmetries = [mp.Mirror(mp.X,phase=-1),
              mp.Mirror(mp.Y,phase=+1)]

sim = mp.Simulation(cell_size=cell_size,
                    geometry=geometry,
                    sources=src,
                    resolution=10,
                    force_complex_fields=True,
                    symmetries=symmetries,
                    boundary_layers=pml_layers)

num_tols = 5
tols = np.power(10, np.arange(-8.0,-8.0-num_tols,-1.0))
ez_dat = np.zeros((122,122,num_tols), dtype=np.complex_)

for i in range(num_tols):
    sim.init_sim()
    sim.solve_cw(tols[i], 10000, 10)
    ez_dat[:,:,i] = sim.get_array(vol=nonpml_vol, component=mp.Ez)

err_dat = np.zeros(num_tols-1)
for i in range(num_tols-1):
    err_dat[i] = LA.norm(ez_dat[:,:,i]-ez_dat[:,:,num_tols-1])

plt.figure(dpi=150)
plt.loglog(tols[:num_tols-1], err_dat, 'bo-');
plt.xlabel("frequency-domain solver tolerance");
plt.ylabel("L2 norm of error in fields");
plt.show()

eps_data = sim.get_array(vol=nonpml_vol, component=mp.Dielectric)
ez_data = np.real(ez_dat[:,:,num_tols-1])

plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

if np.all(np.diff(err_dat) < 0):
    print("PASSED solve_cw test: error in the fields is decreasing with increasing resolution")
else:
    print("FAILED solve_cw test: error in the fields is NOT decreasing with increasing resolution")
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00155282 s
# Working in 2D dimensions.
# Computational cell is 34 x 34 x 0 with resolution 10
#      cylinder, center = (0,0,0)
#           radius 11, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.0736,2.0736,2.0736)
#      cylinder, center = (0,0,0)
#           radius 10, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.087213 s
# -----------
# Meep: using complex fields.
# residual[49] = 0.0369932
# on time step 962 (time=48.1), 0.00418402 s/step
# on time step 1936 (time=96.8), 0.0041071 s/step
# residual[98] = 0.0396893
# on time step 2902 (time=145.1), 0.00414263 s/step
# residual[147] = 0.0230564
# on time step 3869 (time=193.45), 0.00413789 s/step
# residual[196] = 0.0216973
# on time step 4845 (time=242.25), 0.00409981 s/step
# residual[245] = 0.0237527
# on time step 5782 (time=289.1), 0.0042751 s/step
# residual[292] = 0.0381292
# on time step 6744 (time=337.2), 0.00415944 s/step
