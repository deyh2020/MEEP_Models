# %%
import meep as mp
import numpy as np
from datetime import date
import pickle,json
import MyMeepFunctions as myF
import matplotlib.pyplot as plt 



Gap = 6.434e-01


fsrc = 1/1.5475 # frequency of eigenmode or constant-amplitude source
df = 16e-3


nfreq = 100
resolution = 10 #pixels per distance unit, so 10 px/um rn. (ideal)


#flux_freqs = mp.get_flux_freqs(src)

sim,src,tran,sphereMode = myF.buildWGMmodel(40,1/2,Gap,fsrc,df,resolution,nfreq)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(dpi=200)
sim.plot2D(plot_sources_flag=True,plot_monitors_flag=True)
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000252008 s
# Working in 2D dimensions.
# Computational cell is 100 x 100 x 0 with resolution 10
#      block, center = (0,-41.1434,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.0736,2.0736,2.0736)
#      cylinder, center = (0,0,0)
#           radius 40, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.0736,2.0736,2.0736)
# time for set_epsilon = 1.99798 s
# -----------
# MPB solved for frequency_1(0.4,0,0) = 0.325405 after 9 iters

# %%
t = (1e-6/3e8)
tFactor = 1e-15/t # converts femptoseconds into unitless MEEP 

Simtime = 1e3 #in femptoseconds

#sim.reset_meep()
sim.run(until=(Simtime*tFactor))
# Out:
# FloatProgress(value=300.04998779296875, description='0% done ', max=600.0499877929688, min=300.04998779296875)
# on time step 6001 (time=300.05), 5.40907 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-75c244a4b354> in <module>
#       5
#       6 #sim.reset_meep()
# ----> 7 sim.run(until=(Simtime*tFactor))
#
# ~/anaconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py in run(self, *step_funcs, **kwargs)
#    3645             self._run_sources_until(until_after_sources, step_funcs)
#    3646         elif until is not None:
# -> 3647             self._run_until(until, step_funcs)
#    3648         else:
#    3649             raise ValueError("Invalid run configuration")
#
# ~/anaconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py in _run_until(self, cond, step_funcs)
#    2193         while not any([x(self) for x in cond]):
#    2194             for func in step_funcs:
# -> 2195                 _eval_step_func(self, func, 'step')
#    2196             self.fields.step()
#    2197
#
# ~/anaconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py in _eval_step_func(sim, func, todo)
#    4029     elif num_args == 1:
#    4030         if todo == 'step':
# -> 4031             func(sim)
#    4032     elif num_args == 2:
#    4033         func(sim, todo)
#
# ~/anaconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py in _disp(sim)
#    4367
#    4368     def _disp(sim):
# -> 4369         t1 = mp.wall_time()
#    4370         if t1 - closure['tlast'] >= dt:
#    4371             msg_fmt = "Meep progress: {}/{} = {:.1f}% done in {:.1f}s, {:.1f}s to go"
#
# KeyboardInterrupt:

# %%
plt.figure(dpi=200)
sim.plot2D(fields=mp.Ez,plot_sources_flag=True,plot_monitors_flag=True)
plt.show()

# %%
mp.get_fluxes(tran)
# Out:
# [0.00023021960446018298,
#  0.0002300975232128978,
#  0.0002299754398710377,
#  0.0002298533476643039,
#  0.00022973124070637185,
#  0.00022960911404118668,
#  0.00022948696368146293,
#  0.00022936478663915737,
#  0.00022924258094799286,
#  0.00022912034567745826,
#  0.00022899808093809,
#  0.00022887578787869032,
#  0.0002287534686747646,
#  0.00022863112650853114,
#  0.00022850876554099495,
#  0.000228386390875533,
#  0.00022826400851470922,
#  0.0002281416253087087,
#  0.0002280192488978243,
#  0.00022789688764779826,
#  0.00022777455058012718,
#  0.00022765224729624095,
#  0.00022752998789764332,
#  0.00022740778290184586,
#  0.0002272856431548576,
#  0.00022716357974181007,
#  0.00022704160389406104,
#  0.00022691972689754027,
#  0.00022679795999887831,
#  0.00022667631431285963,
#  0.00022655480073086815,
#  0.0002264334298309611,
#  0.00022631221179160828,
#  0.00022619115630738532,
#  0.0002260702725099176,
#  0.0002259495688929124,
#  0.0002258290532426401,
#  0.00022570873257426528,
#  0.00022558861307482407,
#  0.0002254687000525779,
#  0.00022534899789394334,
#  0.0002252295100279021,
#  0.00022511023889832985,
#  0.00022499118594434734,
#  0.00022487235158901643,
#  0.00022475373523625936,
#  0.00022463533527612316,
#  0.00022451714909839162,
#  0.00022439917311424052,
#  0.00022428140278612314,
#  0.000224163832665028,
#  0.00022404645643537606,
#  0.0002239292669669621,
#  0.00022381225637328734,
#  0.0002236954160763004,
#  0.00022357873687638946,
#  0.00022346220902775117,
#  0.00022334582231771166,
#  0.00022322956615014247,
#  0.0002231134296316044,
#  0.00022299740166016366,
#  0.0002228814710154932,
#  0.00022276562644979648,
#  0.00022264985677971556,
#  0.0002225341509756287,
#  0.00022241849825211887,
#  0.00022230288815434357,
#  0.0002221873106426403,
#  0.00022207175617320804,
#  0.00022195621577477263,
#  0.00022184068112049305,
#  0.0002217251445945569,
#  0.00022160959935272053,
#  0.0002214940393766132,
#  0.00022137845952133057,
#  0.00022126285555539862,
#  0.0002211472241938828,
#  0.00022103156312307335,
#  0.00022091587101773601,
#  0.000220800147549738,
#  0.00022068439338908302,
#  0.00022056861019622063,
#  0.00022045280060698392,
#  0.00022033696820864275,
#  0.0002202211175091245,
#  0.00022010525389792895,
#  0.00021998938360079829,
#  0.00021987351362658548,
#  0.00021975765170863,
#  0.00021964180623996205,
#  0.0002195259862028516,
#  0.00021941020109433505,
#  0.0002192944608470073,
#  0.00021917877574671493,
#  0.00021906315634722122,
#  0.00021894761338286188,
#  0.0002188321576800714,
#  0.00021871680006774064,
#  0.00021860155128830032,
#  0.00021848642190885577]

# %%
 sim.get_dft_array(sphereMode,mp.Ez,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f9fe1a76ade1> in <module>
# ----> 1 sim.get_dft_array(sphereMode,mp.Ez,1)
#
# ~/anaconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py in get_dft_array(self, dft_obj, component, num_freq)
#    3242             return mp.get_dft_near2far_array(self.fields, dft_swigobj, component, num_freq)
#    3243         else:
# -> 3244             raise ValueError("Invalid type of dft object: {}".format(dft_swigobj))
#    3245
#    3246     def get_source(self, component, vol=None, center=None, size=None):
#
# ValueError: Invalid type of dft object: None
